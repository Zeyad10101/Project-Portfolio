# %%
#pandas library
import pandas as pd

# %%
fcsv = "https://raw.githubusercontent.com/multidis/hult-social-media-analytics/main/data/uci_fb_metrics.csv"

# %%
df = pd.read_csv(fcsv)
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df.shape
# Out:
# (500, 19)

# %%
df["Type"]
# Out:
# 0       Photo
# 1      Status
# 2       Photo
# 3       Photo
# 4       Photo
#         ...
# 495     Photo
# 496     Photo
# 497     Photo
# 498     Photo
# 499     Photo
# Name: Type, Length: 500, dtype: object

# %%
df["Type"].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
df[df["Type"] == 'Link']
# Out:
#      Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22             138414  Link         1          12             7         10
# 41             138895  Link         1          12             6          3
# 43             138353  Link         1          12             5          3
# 45             138353  Link         1          12             4          3
# 47             138353  Link         1          12             3          2
# 49             138353  Link         1          12             2          2
# 86             137177  Link         1          11             4          3
# 136            136393  Link         1          10             5         10
# 140            136013  Link         1          10             4          3
# 149            135713  Link         1          10             6         11
# 344            117764  Link         1           5             1          2
# ...

# %%
len(df[df["Type"] == 'Link'])
# Out:
# 22

# %%
# number of posts of each type
for tp in df["Type"].unique():
    ntp = len(df[df["Type"] == tp])
    print(f" Post type {tp} occcurs {ntp} times")
# Out:
#  Post type Photo occcurs 426 times
#  Post type Status occcurs 45 times
#  Post type Link occcurs 22 times
#  Post type Video occcurs 7 times

# %%
# fraction of paid entries
df["Paid"].sum()/ df.shape[0]
# Out:
# 0.278

# %%
# average shares of ("share"-column)
#photo-type posts (.mean() in pandas
df[df["Type"] == 'Photo']["share"].mean()
# Out:
# 27.158767772511847

# %%
# print average likes of each post type
for tp in df["Type"].unique():
    like = df[df["Type"] == tp]["like"].mean()
    print(f" Post type {tp} was liked {int(like)} times")
# Out:
#  Post type Photo was liked 182 times
#  Post type Status was liked 176 times
#  Post type Link was liked 73 times
#  Post type Video was liked 231 times

# %%
df[df["Type"] == 'Photo']["like"].mean()
# Out:
# 182.61176470588236
